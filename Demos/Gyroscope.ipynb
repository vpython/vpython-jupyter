# %%
from vpython import *

# Gyroscope sitting on a pedestal

# The analysis is in terms of Lagrangian mechanics.
# The Lagrangian variables are polar angle theta,
# azimuthal angle phi, and spin angle psi.

scene.width = 800
scene.height = 600
scene.range = 1.2
scene.title = "A precessing, nutating gyroscope"

Lshaft = 1 # length of gyroscope shaft
r = Lshaft/2 # distance from support to center of mass
Rshaft = 0.03 # radius of gyroscope shaft
M = 1 # mass of gyroscope (massless shaft)
Rrotor = 0.4 # radius of gyroscope rotor
Drotor = 0.1 # thickness of gyroscope rotor
I3 = 0.5*M*Rrotor**2 # moment of inertia of gyroscope about its own axis
I1 = M*r**2 + .5*I3 # moment of inertia about a line through the support, perpendicular to the axis
hpedestal = Lshaft # height of pedestal
wpedestal = 0.1 # width of pedestal
tbase = 0.05 # thickness of base
wbase = 3*wpedestal # width of base
g = 9.8
Fgrav = vector(0,-M*g,0)
top = vector(0,0,0) # top of pedestal

shaft = cylinder(radius=Rshaft, color=color.orange)
rotor = cylinder(pos=vector(Lshaft/2,0,0), axis=vector(Drotor, 0, 0),
                 radius=Rrotor, color=color.gray(0.9))
base = sphere(color=shaft.color, radius=shaft.radius)
gyro = compound([shaft, rotor, base])
gyro.texture = textures.metal
tip = sphere(color=shaft.color, radius=shaft.radius, texture=textures.metal, make_trail=True, retain=150)
tip.trail_color = color.green
tip.trail_radius = 0.15*shaft.radius

theta = 0
thetadot = 0
psi = 0
psidot = 0
phi = 0
phidot = 0
pureprecession = False

def reset():
    global theta, thetadot, psi, psidot, phi, phidot
    theta = 0.3*pi # initial polar angle of shaft (from vertical)
    thetadot = 0 # initial rate of change of polar angle
    psi = 0 # initial spin angle
    psidot = 30 # initial rate of change of spin angle (spin ang. velocity)
    phi = -pi/2 # initial azimuthal angle
    phidot = 0 # initial rate of change of azimuthal angle
    if pureprecession: # Set to True if you want pure precession, without nutation
        a = (1-I3/I1)*sin(theta)*cos(theta)
        b = -(I3/I1)*psidot*sin(theta)
        c = M*g*r*sin(theta)/I1
        phidot = (-b+sqrt(b**2-4*a*c))/(2*a)
    gyro.axis = vector(sin(theta)*sin(phi),cos(theta),sin(theta)*cos(phi))
    tip.pos = Lshaft*gyro.axis
    tip.clear_trail()

reset()

pedestal = box(pos=top-vector(0,hpedestal/2+shaft.radius/2,0), 
               height=hpedestal-shaft.radius, length=wpedestal, width=wpedestal, texture=textures.wood)
pedastal_base = box(pos=top-vector(0,hpedestal+tbase/2,0), 
                    height=tbase, length=wbase, width=wbase, texture=textures.wood)

dt = 0.0001
t = 0
Nsteps = 20 # number of calculational steps between graphics updates

while True:
    rate(200)
    for step in range(Nsteps): # multiple calculation steps for accuracy
        # Calculate accelerations of the Lagrangian coordinates:
        atheta = sin(theta)*cos(theta)*phidot**2+( M*g*r*sin(theta)-I3*(psidot+phidot*cos(theta))*phidot*sin(theta))/I1
        aphi = (I3/I1)*(psidot+phidot*cos(theta))*thetadot/sin(theta)-2*cos(theta)*thetadot*phidot/sin(theta)
        apsi = phidot*thetadot*sin(theta)-aphi*cos(theta)
        # Update velocities of the Lagrangian coordinates:
        thetadot += atheta*dt
        phidot += aphi*dt
        psidot += apsi*dt
        # Update Lagrangian coordinates:
        theta += thetadot*dt
        phi += phidot*dt
        psi += psidot*dt

    gyro.axis = vector(sin(theta)*sin(phi),cos(theta),sin(theta)*cos(phi))
    # Display approximate rotation of rotor and shaft:
    gyro.rotate(angle=psidot*dt*Nsteps)
    tip.pos = Lshaft*gyro.axis
    t = t+dt*Nsteps
# Out:
# <div id="glowscript" class="glowscript"></div>
# Exception in thread Thread-12:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-13:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-14:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-15:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-17:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-18:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-19:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-20:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-22:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-23:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-24:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-25:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-26:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-27:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-28:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-29:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-30:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-31:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-32:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-33:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-34:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-35:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-36:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-37:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-38:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-39:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-40:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-41:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-42:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-43:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-44:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-45:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-46:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-47:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-48:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-49:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-50:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-51:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-52:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-53:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-54:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-55:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-56:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-57:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-58:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-59:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-60:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-61:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-62:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-63:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-64:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-65:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-66:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-67:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-68:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-69:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-70:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-71:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-72:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-73:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-74:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-75:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-76:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-77:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-78:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-79:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-80:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-81:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-82:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-83:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-84:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-85:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-86:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-87:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
# ...
# KeyError: 'clear_trail'
#
# Exception in thread Thread-955:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-956:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-957:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-958:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-959:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-960:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-961:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-962:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-963:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-964:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-965:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-966:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-967:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-968:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-969:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-970:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-971:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-972:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-973:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-974:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-975:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-976:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-977:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-978:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
#
# Exception in thread Thread-979:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 1180, in run
#     self.function(*self.args, **self.kwargs)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 439, in commsend
#     send = convert_json(commcmds[:L])
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 149, in convert_json
#     send = encode_attr(req)
#   File "C:\Anaconda3\lib\site-packages\vpython\vpython.py", line 121, in encode_attr
#     s = str(d['idx'])+methods[sendval]
# KeyError: 'clear_trail'
